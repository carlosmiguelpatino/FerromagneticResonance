# %%
import pandas as pd
import numpy as np
import seaborn as sb
from scipy.fftpack import fft, fftfreq, fftshift
import matplotlib.pylab as plt
# %matplotlib inline

# %%
data = pd.read_csv("test.csv")

# %%
data.head()
# Out:
#      Oxs_TimeDriver::Simulation time (s)   Oxs_TimeDriver::mz
# 0                           0.000000e+00             0.009998
# 1                           2.028719e-15             0.009927
# 2                           1.014360e-14             0.009647
# 3                           4.260311e-14             0.008525
# 4                           1.724411e-13             0.004039

# %%
data.columns = ["Time", "mz"]

# %%
#sb.regplot(x = data['Time'], y = data['mz'], scatter = True, fit_reg=False)
plt.plot(data['Time'], data['mz'])

# %%
dt = data['Time'][1] - data['Time'][0]
n = len(data['mz']) 
mz_fft = fft(data['mz'])/n
freq = fftfreq(n, dt)


#Shift frequencies
mz_fft_shifted = np.fft.fftshift(mz_fft)
freq_shifted = np.fft.fftshift(freq)

# %%
plt.plot(freq_shifted, abs(mz_fft_shifted))
plt.xlim(0, 0.4e14)
# Out:
# (0, 40000000000000.0)

# %%
max_freq = freq[mz_fft.argmax()]
print('The dominating frequency is {0:.3g} Hz'.format(max_freq))
# Out:
# The dominating frequency is 1.13e+13 Hz
