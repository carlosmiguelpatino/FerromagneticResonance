# %%
import pandas as pd
import seaborn as sb
from scipy.fftpack import fft, fftfreq, fftshift

# %%
data = pd.read_csv("test.csv")

# %%
data.columns = ["Time", "mz"]

# %%
sb.regplot(x = data['Time'], y = data['mz'], scatter = True, fit_reg=False)

# %%
time_step = data['Time'][1]- data['Time'][0]
mz_fft = fft(data['mz'])
freq = fftfreq(len(mz_fft), time_step)

# %%
sb.regplot(x = freq, y = mz_fft, scatter = True, fit_reg=False)
# Out:
# /home/carlosmiguelpatino/Software/anaconda3/lib/python3.5/site-packages/numpy/core/numeric.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/carlosmiguelpatino/Software/anaconda3/lib/python3.5/site-packages/numpy/core/numeric.py:525: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
max_mzft = max(mz_fft)
max_freq = freq[mz_fft.argmax()]
print(max_freq, max_mzft)
# Out:
# -10880821238.5 (2.03882283507+0.848344027559j)
